# %% [markdown]
# # Debug demo
# 在 Notebook 中调试核心解析逻辑（无需 GUI）。

# %%
from log_extractor.config_rules import RULES_BY_TYPE
from log_extractor.parser import parse_file
from log_extractor.excel_writer import rows_to_dataframe

fp = r"samples/sample.log"  # 替换为你的真实日志路径
rows = parse_file(fp, rules=RULES_BY_TYPE['liquid'], components=['S1','S2'], data_type='liquid')
df = rows_to_dataframe(rows)
df.head(10)
